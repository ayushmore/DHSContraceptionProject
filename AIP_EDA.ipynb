# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AIP_DATA/india_couples_dataset.csv")
df.head()
# Out:
# C:\Users\Ayush More\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (72,73,222,223,224,225,226,227,228,229,230,231,232,302,303,304,305,306,307,308,309,310,311,312,322,323,324,325,326,327,328,329,330,331,332,402,403,404,405,406,407,408,409,410,411,412,422,423,424,425,426,427,428,429,430,431,432,478,479,481,482,483,484,485,486,487,488,489,490,501,502,503,504,505,506,507,508,509,510,511,532,598,672,1151,1262,1324,1399,1400,1461,1462,1529,1530,1533,1548,1549,1567,1598,1612,1613,1669,1670,1671,1698,1699,1700,1704,1705,1706,1716,1717,1718,1722,1723,1724,1728,1729,1730,1734,1735,1736,1740,1741,1742,1758,1759,1760,1764,1765,1766,1770,1771,1772,1776,1777,1778,1794,1795,1796,1800,1801,1802,1806,1807,1808,1835,1836,1853,1854,1855,1889,1890,1961,1962,1963,1979,1980,1981,1997,1998,1999,2015,2016,2086,2204,2207,2210,2211,2213,2214,2226,2227,2228,2229,2230,2231,2232,2233,2234,2235,2236,2237,2238,2239,2242,2243,2244,2245,2246,2247,2248,2249,2266,2284,2285,228
# ...

# %%
data_vars = pd.read_csv("AIP_DATA/AIP_VARIABLES.csv")
data_vars.columns = ["Variables", "Definition", "Include"]
key_vals = data_vars[data_vars["Include"] == 1]
key_vals[key_vals["Variables"] == "v312"]

outcome_categories = pd.read_csv("AIP_DATA/Outcome_categories.csv")
outcome_categories["Label"] = "Method Currently Used: " + outcome_categories["Label"]
outcome_categories

adjust_outcome = pd.read_csv("AIP_DATA/Outcome_categories.csv")
rename_labels = {"Not Using Any Method": "not using", "Male Condom": "condom", 
        "Periodic Abstinense (Rhythm)": "rhythm/periodic abstinence", "Male Strilization": "male sterilization",
        "Lactational ammenorhea": "lactational amenorrhea (lam)", "Foam and Jelly": "Foam or Jelly",
        "Standard Days method": "standard days", "Withdrawl": "withdrawal"}
adjust_outcome["Label"] = adjust_outcome["Label"].replace(rename_labels).str.lower()
adjust_outcome = adjust_outcome.drop(columns = ["Code"])
adjust_outcome = adjust_outcome.rename(columns = {"Label": "Current contraceptive method"})
adjust_outcome
# Out:
#     Current contraceptive method      Category 1 (2-levels)  \
# 0                      not using  No or Traditional Methods
# 1                           pill          Any Modern Method
# 2                            iud          Any Modern Method
# 3                     injections          Any Modern Method
# 4                      diaphragm          Any Modern Method
# 5                         condom          Any Modern Method
# 6           female sterilization          Any Modern Method
# 7             male sterilization          Any Modern Method
# 8     rhythm/periodic abstinence  No or Traditional Methods
# 9                     withdrawal  No or Traditional Methods
# 10             other traditional  No or Traditional Methods
# 11                       impants          Any Modern Method
# 12          prolonged abstinence  No or Traditional Methods
# 13  lactational amenorrhea (lam)  No or Traditional Methods
# 14                 female condom          Any Modern Method
# ...

# %%
variable_col = key_vals["Variables"].tolist()
description_col = key_vals["Definition"].tolist()

x = key_vals[key_vals["Variables"].str.contains("v307")]
v307_names = ["Pill", "IUD", "Inj.", "Dia.", "M.C.", "F.S.", "M.S.", "P.A.", "With.", "O.T.", "Imp.", "Abs.", "Lac.", "F.C", "F&J.", "E.C.", "O.M.", "STM", "CS1", "CS2"]
v307_names = ["Method Currently Used: " + i for i in v307_names]

labels = outcome_categories["Label"].tolist()

l_idx = 0
for i in range(len(description_col)):
    if description_col[i] == "Method currently used":
        description_col[i] = labels[l_idx]
        l_idx += 1

clean_data_desc = df.filter(items = variable_col)
clean_data_desc.columns = description_col
clean_data_desc

clean_data_labels = df.filter(items = variable_col)
#clean_data_labels
clean_data_desc.head()
# Out:
#    National women's sample weight (6 decimals)  Respondent's month of birth  \
# 0                                       191760                            4
# 1                                       191760                            1
# 2                                       191760                            4
# 3                                       191760                            7
# 4                                       191760                            2
#
#    Respondent's year of birth  Respondent's current age Age in 5-year groups  \
# 0                        1993                        22                20-24
# 1                        1975                        40                40-44
# 2                        1978                        37                35-39
# 3                        1982                        33                30-34
# 4                        1980                        35                35-39
#
# ...

# %%
comb = pd.merge(clean_data_desc, adjust_outcome, on = 'Current contraceptive method', how="left")
n = comb.isnull().mean().sort_values(ascending = False)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(n)
# Out:
# Method Currently Used: Country specific method 1                                    1.000000
# Method Currently Used: Other Traditional                                            1.000000
# Method Currently Used: Impants                                                      1.000000
# Method Currently Used: Standard Days method                                         1.000000
# Method Currently Used: Foam and Jelly                                               1.000000
# Used condom every time had sex with 2nd to most recent partner in last 12 months    0.998917
# Amount of compensation recieved for sterilization                                   0.995588
# Month started using male sterilization                                              0.994270
# Year started using male sterilization                                               0.994270
# Facility sterilization took place                                                   0.994270
# ...

# %%
clean_comb = comb[comb.columns[comb.isnull().mean() < 0.75]]
compression_opts = dict(method='zip',
                        archive_name='clean_data.csv')  
clean_comb.to_csv('clean_data.zip', index=False,
          compression=compression_opts)

# %%
(comb["Current contraceptive method"].value_counts()/len(clean_data_desc)).to_dict()
# Out:
# {'not using': 0.4403259231348907,
#  'female sterilization': 0.33852989198693795,
#  'condom': 0.06888972619944737,
#  'pill': 0.048951268525496104,
#  'rhythm/periodic abstinence': 0.03865234865611655,
#  'withdrawal': 0.03505714644561668,
#  'iud': 0.021445616679226325,
#  'male sterilization': 0.0043173825671941725,
#  'injections': 0.002496232102486812,
#  'lactational amenorrhea (lam)': 0.0010675709620698317,
#  'female condom': 0.00014129615674453655,
#  'standard days': 0.0001098970108013062,
#  'foam or jelly': 1.569957297161517e-05}

# %%
comb["Current contraceptive method"].value_counts()
# Out:
# not using                       28047
# female sterilization            21563
# condom                           4388
# pill                             3118
# rhythm/periodic abstinence       2462
# withdrawal                       2233
# iud                              1366
# male sterilization                275
# injections                        159
# lactational amenorrhea (lam)       68
# female condom                       9
# standard days                       7
# foam or jelly                       1
# Name: Current contraceptive method, dtype: int64

# %%
clean_data_desc.shape
# Out:
# (63696, 170)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(clean_data_desc.iloc[0])
# Out:
# National women's sample weight (6 decimals)                                                                  191760
# Respondent's month of birth                                                                                       4
# Respondent's year of birth                                                                                     1993
# Respondent's current age                                                                                         22
# Age in 5-year groups                                                                                          20-24
# Result of individual interview                                                                            completed
# Ever-married sample                                                                                all woman sample
# State                                                                                   andaman and nicobar islands
# ...
